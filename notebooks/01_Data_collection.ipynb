# %%
from Bio import Entrez
import pandas as pd

# %%
Entrez.email = "hekaybob5522@gmail.com"

# %% [markdown]
# ETL PIPELINE

# %%
from src.data_collection import search_pubmed
pmids = search_pubmed('lung cancer biomarker', retmax=100)
print(len(pmids))
print(pmids)
# Out:
# 100
# ...

# %%
from src.data_collection import fetch_papers
fetch_papers(pmids)
# Out:
#         PMID                                              Title  \
# 0   42324360  A decade of progress in small-cell lung cancer...
# 1   42323710  Extracellular vesicles as diagnostic and progn...
# 2   42323489  Who Gets Left Out of Precision Oncology? Real-...
# 3   42322507  Pan-cancer integrative profiling of immune-rel...
# 4   42322411  Single-cell and multi-omics integration deline...
# ..       ...                                                ...
# 95  42291360  CEACAM5 as a biomarker of semi-solid, lepidic ...
# 96  42291356  <i>ZNF528</i> as a novel driver of metastasis ...
# 97  42291350  Advances in translational lung cancer research...
# 98  42291348  Major histocompatibility complex II serves as ...
# 99  42291343  Elevated baseline C-reactive protein predicts ...
#
#                                              Abstract  Year
# 0   Small-cell lung cancer (SCLC) accounts for 13-...  2026
# 1   Non-small cell lung cancer (NSCLC) remains the...  2026
# ...

# %%
df = pd.DataFrame(fetch_papers(pmids))

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PMID      100 non-null    str
#  1   Title     100 non-null    str
#  2   Abstract  100 non-null    str
#  3   Year      91 non-null     str
# dtypes: str(4)
# memory usage: 203.0 KB
# PMID        0
# Title       0
# Abstract    0
# Year        9
# dtype: int64

# %%
df.shape
# Out:
# (100, 4)

# %%
df.head()
# Out:
#        PMID                                              Title  \
# 0  42324360  A decade of progress in small-cell lung cancer...
# 1  42323710  Extracellular vesicles as diagnostic and progn...
# 2  42323489  Who Gets Left Out of Precision Oncology? Real-...
# 3  42322507  Pan-cancer integrative profiling of immune-rel...
# 4  42322411  Single-cell and multi-omics integration deline...
#
#                                             Abstract  Year
# 0  Small-cell lung cancer (SCLC) accounts for 13-...  2026
# 1  Non-small cell lung cancer (NSCLC) remains the...  2026
# 2  Precision oncology in non-small cell lung canc...  2026
# 3  Long non-coding RNAs (lncRNAs) have been widel...  2026
# 4  Gene-wise intratumor heterogeneity (ITH), defi...  2026

# %%
df.to_csv("../data/raw/pubmed_papers.csv", index = False)
