# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/pubmed_papers.csv")

# %%
from src.embedding import load_embedding_model, generate_embedding
model = load_embedding_model()
embeddings = generate_embedding(df, model)
print(embeddings.shape)
# Out:
# ...
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# (100, 384)
