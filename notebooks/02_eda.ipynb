# %%
from Bio import Entrez
import pandas as pd

print("Loaded successfully")
# Out:
# Loaded successfully

# %%
df = pd.read_csv("../data/raw/pubmed_papers.csv")
df.head()
# Out:
#        PMID                                              Title  \
# 0  42270077  PRMT5-mediated methylation of LKB1 controls PD...
# 1  42268896  High-throughput screening identifies a critica...
# 2  42268565  Global characterization of extrachromosomal ci...
# 3  42268452  Can alterations in miR-21, miR-1, and miR-224 ...
# 4  42268347  Context-dependent roles of lncRNA JPX in human...
#
#                                             Abstract  Year
# 0  Immune checkpoint blockade (ICB) targeting the...  2026
# 1  Lung adenocarcinoma (LUAD) is the most common ...  2026
# 2  Non-small cell lung cancer (NSCLC) is a partic...  2026
# 3  Lung cancer is a leading cause of cancer-relat...  2026
# 4  JPX is a long non-coding RNA involved in X-chr...  2026

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PMID      100 non-null    int64
#  1   Title     100 non-null    str
#  2   Abstract  100 non-null    str
#  3   Year      100 non-null    int64
# dtypes: int64(2), str(2)
# memory usage: 194.6 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df.isnull().sum()
# Out:
# PMID        0
# Title       0
# Abstract    0
# Year        0
# dtype: int64

# %%
df['Year'].value_counts()
# Out:
# Year
# 2026    99
# 2025     1
# Name: count, dtype: int64

# %%
df['Abstract_length'] = df['Abstract'].str.split().str.len()
df['Abstract_length']
# Out:
# 0     251
# 1     191
# 2     235
# 3     220
# 4     228
#      ...
# 95    468
# 96    253
# 97    272
# 98    166
# 99    156
# Name: Abstract_length, Length: 100, dtype: int64

# %%
df['Abstract_length'].describe()
# Out:
# count    100.000000
# mean     245.400000
# std       87.098458
# min       90.000000
# 25%      198.750000
# 50%      239.000000
# 75%      261.250000
# max      783.000000
# Name: Abstract_length, dtype: float64

# %%
df['Abstract_length'].describe(percentiles=[0.01, 0.99])
# Out:
# count    100.000000
# mean     245.400000
# std       87.098458
# min       90.000000
# 1%       127.620000
# 99%      486.000000
# max      783.000000
# Name: Abstract_length, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(df['Abstract_length'])
plt.title('Abstract Length Distributer')
plt.xlabel('Words')
plt.ylabel('Paper counts')
plt.show()
